# %%
import os
import sys

import pandas as pd

# %%
RAW_DATA_PATH = "data/raw/deepglobe-2018-dataset/"
METADATA_FILE = "metadata.csv"
CLASS_FILE = "class_dict.csv"

TARGET_DATA_PATH = "data/splitted/deepglobe-2018-dataset/"

# %%
metadata_df = pd.read_csv(os.path.join(RAW_DATA_PATH, METADATA_FILE))
metadata_df
# Out:
#       image_id  split        sat_image_path              mask_path
# 0       100694  train  train/100694_sat.jpg  train/100694_mask.png
# 1       102122  train  train/102122_sat.jpg  train/102122_mask.png
# 2        10233  train   train/10233_sat.jpg   train/10233_mask.png
# 3       103665  train  train/103665_sat.jpg  train/103665_mask.png
# 4       103730  train  train/103730_sat.jpg  train/103730_mask.png
# ...        ...    ...                   ...                    ...
# 1141    979233   test   test/979233_sat.jpg                    NaN
# 1142    983689   test   test/983689_sat.jpg                    NaN
# 1143    988205   test   test/988205_sat.jpg                    NaN
# 1144    989953   test   test/989953_sat.jpg                    NaN
# 1145    999380   test   test/999380_sat.jpg                    NaN
#
# [1146 rows x 4 columns]

# %%
os.makedirs(os.path.join(TARGET_DATA_PATH, "train/images"), exist_ok=True)
os.makedirs(os.path.join(TARGET_DATA_PATH, "train/masks"), exist_ok=True)
os.makedirs(os.path.join(TARGET_DATA_PATH, "valid/images"), exist_ok=True)
os.makedirs(os.path.join(TARGET_DATA_PATH, "valid/masks"), exist_ok=True)
os.makedirs(os.path.join(TARGET_DATA_PATH, "test/images"), exist_ok=True)
os.makedirs(os.path.join(TARGET_DATA_PATH, "test/masks"), exist_ok=True)

# %%
meta_list = metadata_df.to_dict(orient="records")
meta_list
# Out:
# [{'image_id': 100694,
#   'split': 'train',
#   'sat_image_path': 'train/100694_sat.jpg',
#   'mask_path': 'train/100694_mask.png'},
#  {'image_id': 102122,
#   'split': 'train',
#   'sat_image_path': 'train/102122_sat.jpg',
#   'mask_path': 'train/102122_mask.png'},
#  {'image_id': 10233,
#   'split': 'train',
#   'sat_image_path': 'train/10233_sat.jpg',
#   'mask_path': 'train/10233_mask.png'},
#  {'image_id': 103665,
#   'split': 'train',
#   'sat_image_path': 'train/103665_sat.jpg',
#   'mask_path': 'train/103665_mask.png'},
#  {'image_id': 103730,
#   'split': 'train',
#   'sat_image_path': 'train/103730_sat.jpg',
#   'mask_path': 'train/103730_mask.png'},
#  {'image_id': 104113,
#   'split': 'train',
#   'sat_image_path': 'train/104113_sat.jpg',
#   'mask_path': 'train/104113_mask.png'},
#  {'image_id': 10452,
#   'split': 'train',
#   'sat_image_path': 'train/10452_sat.jpg',
#   'mask_path': 'train/10452_mask.png'},
#  {'image_id': 10901,
#   'split': 'train',
#   'sat_image_path': 'train/10901_sat.jpg',
#   'mask_path': 'train/10901_mask.png'},
#  {'image_id': 111335,
#   'split': 'train',
#   'sat_image_path': 'train/111335_sat.jpg',
#   'mask_path': 'train/111335_mask.png'},
#  {'image_id': 114433,
#   'split': 'train',
#   'sat_image_path': 'train/114433_sat.jpg',
#   'mask_path': 'train/114433_mask.png'},
#  {'image_id': 114473,
#   'split': 'train',
#   'sat_image_path': 'train/114473_sat.jpg',
#   'mask_path': 'train/114473_mask.png'},
#  {'image_id': 114577,
#   'split': 'train',
#   'sat_image_path': 'train/114577_sat.jpg',
#   'mask_path': 'train/114577_mask.png'},
#  {'image_id': 115444,
#   'split': 'train',
#   'sat_image_path': 'train/115444_sat.jpg',
#   'mask_path': 'train/115444_mask.png'},
#  {'image_id': 119012,
#   'split': 'train',
#   'sat_image_path': 'train/119012_sat.jpg',
#   'mask_path': 'train/119012_mask.png'},
#  {'image_id': 119079,
#   'split': 'train',
#   'sat_image_path': 'train/119079_sat.jpg',
#   'mask_path': 'train/119079_mask.png'},
#  {'image_id': 119,
#   'split': 'train',
#   'sat_image_path': 'train/119_sat.jpg',
#   'mask_path': 'train/119_mask.png'},
#  {'image_id': 120245,
#   'split': 'train',
#   'sat_image_path': 'train/120245_sat.jpg',
#   'mask_path': 'train/120245_mask.png'},
#  {'image_id': 120625,
#   'split': 'train',
#   'sat_image_path': 'train/120625_sat.jpg',
#   'mask_path': 'train/120625_mask.png'},
#  {'image_id': 122104,
#   'split': 'train',
#   'sat_image_path': 'train/122104_sat.jpg',
#   'mask_path': 'train/122104_mask.png'},
#  {'image_id': 122178,
#   'split': 'train',
#   'sat_image_path': 'train/122178_sat.jpg',
#   'mask_path': 'train/122178_mask.png'},
#  {'image_id': 123172,
#   'split': 'train',
#   'sat_image_path': 'train/123172_sat.jpg',
#   'mask_path': 'train/123172_mask.png'},
#  {'image_id': 124529,
#   'split': 'train',
#   'sat_image_path': 'train/124529_sat.jpg',
#   'mask_path': 'train/124529_mask.png'},
#  {'image_id': 125510,
#   'split': 'train',
#   'sat_image_path': 'train/125510_sat.jpg',
#   'mask_path': 'train/125510_mask.png'},
#  {'image_id': 125795,
#   'split': 'train',
#   'sat_image_path': 'train/125795_sat.jpg',
#   'mask_path': 'train/125795_mask.png'},
#  {'image_id': 126796,
#   'split': 'train',
#   'sat_image_path': 'train/126796_sat.jpg',
#   'mask_path': 'train/126796_mask.png'},
#  {'image_id': 127660,
#   'split': 'train',
#   'sat_image_path': 'train/127660_sat.jpg',
#   'mask_path': 'train/127660_mask.png'},
#  {'image_id': 127976,
#   'split': 'train',
#   'sat_image_path': 'train/127976_sat.jpg',
#   'mask_path': 'train/127976_mask.png'},
#  {'image_id': 129297,
#   'split': 'train',
#   'sat_image_path': 'train/129297_sat.jpg',
#   'mask_path': 'train/129297_mask.png'},
#  {'image_id': 129298,
#   'split': 'train',
#   'sat_image_path': 'train/129298_sat.jpg',
#   'mask_path': 'train/129298_mask.png'},
#  {'image_id': 131720,
#   'split': 'train',
#   'sat_image_path': 'train/131720_sat.jpg',
#   'mask_path': 'train/131720_mask.png'},
#  {'image_id': 133209,
#   'split': 'train',
#   'sat_image_path': 'train/133209_sat.jpg',
#   'mask_path': 'train/133209_mask.png'},
#  {'image_id': 133254,
#   'split': 'train',
#   'sat_image_path': 'train/133254_sat.jpg',
#   'mask_path': 'train/133254_mask.png'},
#  {'image_id': 13415,
#   'split': 'train',
#   'sat_image_path': 'train/13415_sat.jpg',
#   'mask_path': 'train/13415_mask.png'},
#  {'image_id': 134465,
#   'split': 'train',
#   'sat_image_path': 'train/134465_sat.jpg',
#   'mask_path': 'train/134465_mask.png'},
#  {'image_id': 136252,
#   'split': 'train',
#   'sat_image_path': 'train/136252_sat.jpg',
#   'mask_path': 'train/136252_mask.png'},
#  {'image_id': 137499,
#   'split': 'train',
#   'sat_image_path': 'train/137499_sat.jpg',
#   'mask_path': 'train/137499_mask.png'},
#  {'image_id': 137806,
#   'split': 'train',
#   'sat_image_path': 'train/137806_sat.jpg',
#   'mask_path': 'train/137806_mask.png'},
#  {'image_id': 139482,
#   'split': 'train',
#   'sat_image_path': 'train/139482_sat.jpg',
#   'mask_path': 'train/139482_mask.png'},
#  {'image_id': 139581,
#   'split': 'train',
#   'sat_image_path': 'train/139581_sat.jpg',
#   'mask_path': 'train/139581_mask.png'},
#  {'image_id': 140299,
#   'split': 'train',
#   'sat_image_path': 'train/140299_sat.jpg',
#   'mask_path': 'train/140299_mask.png'},
#  {'image_id': 141685,
#   'split': 'train',
#   'sat_image_path': 'train/141685_sat.jpg',
#   'mask_path': 'train/141685_mask.png'},
#  {'image_id': 142766,
#   'split': 'train',
#   'sat_image_path': 'train/142766_sat.jpg',
#   'mask_path': 'train/142766_mask.png'},
#  {'image_id': 143353,
#   'split': 'train',
#   'sat_image_path': 'train/143353_sat.jpg',
#   'mask_path': 'train/143353_mask.png'},
#  {'image_id': 143364,
#   'split': 'train',
#   'sat_image_path': 'train/143364_sat.jpg',
#   'mask_path': 'train/143364_mask.png'},
#  {'image_id': 143794,
#   'split': 'train',
#   'sat_image_path': 'train/143794_sat.jpg',
#   'mask_path': 'train/143794_mask.png'},
#  {'image_id': 147545,
#   'split': 'train',
#   'sat_image_path': 'train/147545_sat.jpg',
#   'mask_path': 'train/147545_mask.png'},
#  {'image_id': 147716,
#   'split': 'train',
#   'sat_image_path': 'train/147716_sat.jpg',
#   'mask_path': 'train/147716_mask.png'},
#  {'image_id': 148260,
#   'split': 'train',
#   'sat_image_path': 'train/148260_sat.jpg',
#   'mask_path': 'train/148260_mask.png'},
#  {'image_id': 148381,
#   'split': 'train',
#   'sat_image_path': 'train/148381_sat.jpg',
#   'mask_path': 'train/148381_mask.png'},
#  {'image_id': 149624,
#   'split': 'train',
#   'sat_image_path': 'train/149624_sat.jpg',
#   'mask_path': 'train/149624_mask.png'},
#  {'image_id': 152569,
#   'split': 'train',
#   'sat_image_path': 'train/152569_sat.jpg',
#   'mask_path': 'train/152569_mask.png'},
#  {'image_id': 154124,
#   'split': 'train',
#   'sat_image_path': 'train/154124_sat.jpg',
#   'mask_path': 'train/154124_mask.png'},
#  {'image_id': 154626,
#   'split': 'train',
#   'sat_image_path': 'train/154626_sat.jpg',
#   'mask_path': 'train/154626_mask.png'},
#  {'image_id': 155165,
#   'split': 'train',
#   'sat_image_path': 'train/155165_sat.jpg',
#   'mask_path': 'train/155165_mask.png'},
#  {'image_id': 15573,
#   'split': 'train',
#   'sat_image_path': 'train/15573_sat.jpg',
#   'mask_path': 'train/15573_mask.png'},
#  {'image_id': 156574,
#   'split': 'train',
#   'sat_image_path': 'train/156574_sat.jpg',
#   'mask_path': 'train/156574_mask.png'},
#  {'image_id': 156951,
#   'split': 'train',
#   'sat_image_path': 'train/156951_sat.jpg',
#   'mask_path': 'train/156951_mask.png'},
#  {'image_id': 157839,
#   'split': 'train',
#   'sat_image_path': 'train/157839_sat.jpg',
#   'mask_path': 'train/157839_mask.png'},
#  {'image_id': 158163,
#   'split': 'train',
#   'sat_image_path': 'train/158163_sat.jpg',
#   'mask_path': 'train/158163_mask.png'},
#  {'image_id': 159177,
#   'split': 'train',
#   'sat_image_path': 'train/159177_sat.jpg',
#   'mask_path': 'train/159177_mask.png'},
#  {'image_id': 159280,
#   'split': 'train',
#   'sat_image_path': 'train/159280_sat.jpg',
#   'mask_path': 'train/159280_mask.png'},
#  {'image_id': 159322,
#   'split': 'train',
#   'sat_image_path': 'train/159322_sat.jpg',
#   'mask_path': 'train/159322_mask.png'},
#  {'image_id': 160037,
#   'split': 'train',
#   'sat_image_path': 'train/160037_sat.jpg',
#   'mask_path': 'train/160037_mask.png'},
#  {'image_id': 161109,
#   'split': 'train',
#   'sat_image_path': 'train/161109_sat.jpg',
#   'mask_path': 'train/161109_mask.png'},
#  {'image_id': 161838,
#   'split': 'train',
#   'sat_image_path': 'train/161838_sat.jpg',
#   'mask_path': 'train/161838_mask.png'},
#  {'image_id': 162310,
#   'split': 'train',
#   'sat_image_path': 'train/162310_sat.jpg',
#   'mask_path': 'train/162310_mask.png'},
#  {'image_id': 164029,
#   'split': 'train',
#   'sat_image_path': 'train/164029_sat.jpg',
#   'mask_path': 'train/164029_mask.png'},
#  {'image_id': 16453,
#   'split': 'train',
#   'sat_image_path': 'train/16453_sat.jpg',
#   'mask_path': 'train/16453_mask.png'},
#  {'image_id': 166293,
#   'split': 'train',
#   'sat_image_path': 'train/166293_sat.jpg',
#   'mask_path': 'train/166293_mask.png'},
#  {'image_id': 166805,
#   'split': 'train',
#   'sat_image_path': 'train/166805_sat.jpg',
#   'mask_path': 'train/166805_mask.png'},
#  {'image_id': 168514,
#   'split': 'train',
#   'sat_image_path': 'train/168514_sat.jpg',
#   'mask_path': 'train/168514_mask.png'},
#  {'image_id': 170535,
#   'split': 'train',
#   'sat_image_path': 'train/170535_sat.jpg',
#   'mask_path': 'train/170535_mask.png'},
#  {'image_id': 172307,
#   'split': 'train',
#   'sat_image_path': 'train/172307_sat.jpg',
#   'mask_path': 'train/172307_mask.png'},
#  {'image_id': 172854,
#   'split': 'train',
#   'sat_image_path': 'train/172854_sat.jpg',
#   'mask_path': 'train/172854_mask.png'},
#  {'image_id': 174980,
#   'split': 'train',
#   'sat_image_path': 'train/174980_sat.jpg',
#   'mask_path': 'train/174980_mask.png'},
#  {'image_id': 176112,
#   'split': 'train',
#   'sat_image_path': 'train/176112_sat.jpg',
#   'mask_path': 'train/176112_mask.png'},
#  {'image_id': 176225,
#   'split': 'train',
#   'sat_image_path': 'train/176225_sat.jpg',
#   'mask_path': 'train/176225_mask.png'},
#  {'image_id': 176506,
#   'split': 'train',
#   'sat_image_path': 'train/176506_sat.jpg',
#   'mask_path': 'train/176506_mask.png'},
#  {'image_id': 180902,
#   'split': 'train',
#   'sat_image_path': 'train/180902_sat.jpg',
#   'mask_path': 'train/180902_mask.png'},
#  {'image_id': 181447,
#   'split': 'train',
#   'sat_image_path': 'train/181447_sat.jpg',
#   'mask_path': 'train/181447_mask.png'},
#  {'image_id': 182027,
#   'split': 'train',
#   'sat_image_path': 'train/182027_sat.jpg',
#   'mask_path': 'train/182027_mask.png'},
#  {'image_id': 182422,
#   'split': 'train',
#   'sat_image_path': 'train/182422_sat.jpg',
#   'mask_path': 'train/182422_mask.png'},
#  {'image_id': 185522,
#   'split': 'train',
#   'sat_image_path': 'train/185522_sat.jpg',
#   'mask_path': 'train/185522_mask.png'},
#  {'image_id': 185562,
#   'split': 'train',
#   'sat_image_path': 'train/185562_sat.jpg',
#   'mask_path': 'train/185562_mask.png'},
#  {'image_id': 186739,
#   'split': 'train',
#   'sat_image_path': 'train/186739_sat.jpg',
#   'mask_path': 'train/186739_mask.png'},
#  {'image_id': 192576,
#   'split': 'train',
#   'sat_image_path': 'train/192576_sat.jpg',
#   'mask_path': 'train/192576_mask.png'},
#  {'image_id': 192602,
#   'split': 'train',
#   'sat_image_path': 'train/192602_sat.jpg',
#   'mask_path': 'train/192602_mask.png'},
#  {'image_id': 192918,
#   'split': 'train',
#   'sat_image_path': 'train/192918_sat.jpg',
#   'mask_path': 'train/192918_mask.png'},
#  {'image_id': 194156,
#   'split': 'train',
#   'sat_image_path': 'train/194156_sat.jpg',
#   'mask_path': 'train/194156_mask.png'},
#  {'image_id': 195769,
#   'split': 'train',
#   'sat_image_path': 'train/195769_sat.jpg',
#   'mask_path': 'train/195769_mask.png'},
#  {'image_id': 19627,
#   'split': 'train',
#   'sat_image_path': 'train/19627_sat.jpg',
#   'mask_path': 'train/19627_mask.png'},
#  {'image_id': 200561,
#   'split': 'train',
#   'sat_image_path': 'train/200561_sat.jpg',
#   'mask_path': 'train/200561_mask.png'},
#  {'image_id': 200589,
#   'split': 'train',
#   'sat_image_path': 'train/200589_sat.jpg',
#   'mask_path': 'train/200589_mask.png'},
#  {'image_id': 20187,
#   'split': 'train',
#   'sat_image_path': 'train/20187_sat.jpg',
#   'mask_path': 'train/20187_mask.png'},
#  {'image_id': 202277,
#   'split': 'train',
#   'sat_image_path': 'train/202277_sat.jpg',
#   'mask_path': 'train/202277_mask.png'},
#  {'image_id': 204494,
#   'split': 'train',
#   'sat_image_path': 'train/204494_sat.jpg',
#   'mask_path': 'train/204494_mask.png'},
#  {'image_id': 204562,
#   'split': 'train',
#   'sat_image_path': 'train/204562_sat.jpg',
#   'mask_path': 'train/204562_mask.png'},
#  {'image_id': 207663,
#   'split': 'train',
#   'sat_image_path': 'train/207663_sat.jpg',
#   'mask_path': 'train/207663_mask.png'},
#  {'image_id': 207743,
#   'split': 'train',
#   'sat_image_path': 'train/207743_sat.jpg',
#   'mask_path': 'train/207743_mask.png'},
#  {'image_id': 208495,
#   'split': 'train',
#   'sat_image_path': 'train/208495_sat.jpg',
#   'mask_path': 'train/208495_mask.png'},
#  {'image_id': 208695,
#   'split': 'train',
#   'sat_image_path': 'train/208695_sat.jpg',
#   'mask_path': 'train/208695_mask.png'},
#  {'image_id': 209787,
#   'split': 'train',
#   'sat_image_path': 'train/209787_sat.jpg',
#   'mask_path': 'train/209787_mask.png'},
#  {'image_id': 21023,
#   'split': 'train',
#   'sat_image_path': 'train/21023_sat.jpg',
#   'mask_path': 'train/21023_mask.png'},
#  {'image_id': 210436,
#   'split': 'train',
#   'sat_image_path': 'train/210436_sat.jpg',
#   'mask_path': 'train/210436_mask.png'},
#  {'image_id': 210473,
#   'split': 'train',
#   'sat_image_path': 'train/210473_sat.jpg',
#   'mask_path': 'train/210473_mask.png'},
#  {'image_id': 210669,
#   'split': 'train',
#   'sat_image_path': 'train/210669_sat.jpg',
#   'mask_path': 'train/210669_mask.png'},
#  {'image_id': 211316,
#   'split': 'train',
#   'sat_image_path': 'train/211316_sat.jpg',
#   'mask_path': 'train/211316_mask.png'},
#  {'image_id': 211739,
#   'split': 'train',
#   'sat_image_path': 'train/211739_sat.jpg',
#   'mask_path': 'train/211739_mask.png'},
#  {'image_id': 215525,
#   'split': 'train',
#   'sat_image_path': 'train/215525_sat.jpg',
#   'mask_path': 'train/215525_mask.png'},
#  {'image_id': 217085,
#   'split': 'train',
#   'sat_image_path': 'train/217085_sat.jpg',
#   'mask_path': 'train/217085_mask.png'},
#  {'image_id': 21717,
#   'split': 'train',
#   'sat_image_path': 'train/21717_sat.jpg',
#   'mask_path': 'train/21717_mask.png'},
#  {'image_id': 218329,
#   'split': 'train',
#   'sat_image_path': 'train/218329_sat.jpg',
#   'mask_path': 'train/218329_mask.png'},
#  {'image_id': 219555,
#   'split': 'train',
#   'sat_image_path': 'train/219555_sat.jpg',
#   'mask_path': 'train/219555_mask.png'},
#  {'image_id': 219670,
#   'split': 'train',
#   'sat_image_path': 'train/219670_sat.jpg',
#   'mask_path': 'train/219670_mask.png'},
#  {'image_id': 221278,
#   'split': 'train',
#   'sat_image_path': 'train/221278_sat.jpg',
#   'mask_path': 'train/221278_mask.png'},
#  {'image_id': 225393,
#   'split': 'train',
#   'sat_image_path': 'train/225393_sat.jpg',
#   'mask_path': 'train/225393_mask.png'},
#  {'image_id': 225945,
#   'split': 'train',
#   'sat_image_path': 'train/225945_sat.jpg',
#   'mask_path': 'train/225945_mask.png'},
#  {'image_id': 226788,
#   'split': 'train',
#   'sat_image_path': 'train/226788_sat.jpg',
#   'mask_path': 'train/226788_mask.png'},
#  {'image_id': 229383,
#   'split': 'train',
#   'sat_image_path': 'train/229383_sat.jpg',
#   'mask_path': 'train/229383_mask.png'},
#  {'image_id': 232373,
#   'split': 'train',
#   'sat_image_path': 'train/232373_sat.jpg',
#   'mask_path': 'train/232373_mask.png'},
#  {'image_id': 2334,
#   'split': 'train',
#   'sat_image_path': 'train/2334_sat.jpg',
#   'mask_path': 'train/2334_mask.png'},
#  {'image_id': 233615,
#   'split': 'train',
#   'sat_image_path': 'train/233615_sat.jpg',
#   'mask_path': 'train/233615_mask.png'},
#  {'image_id': 234269,
#   'split': 'train',
#   'sat_image_path': 'train/234269_sat.jpg',
#   'mask_path': 'train/234269_mask.png'},
#  {'image_id': 235869,
#   'split': 'train',
#   'sat_image_path': 'train/235869_sat.jpg',
#   'mask_path': 'train/235869_mask.png'},
#  {'image_id': 238322,
#   'split': 'train',
#   'sat_image_path': 'train/238322_sat.jpg',
#   'mask_path': 'train/238322_mask.png'},
#  {'image_id': 239955,
#   'split': 'train',
#   'sat_image_path': 'train/239955_sat.jpg',
#   'mask_path': 'train/239955_mask.png'},
#  {'image_id': 242583,
#   'split': 'train',
#   'sat_image_path': 'train/242583_sat.jpg',
#   'mask_path': 'train/242583_mask.png'},
#  {'image_id': 244423,
#   'split': 'train',
#   'sat_image_path': 'train/244423_sat.jpg',
#   'mask_path': 'train/244423_mask.png'},
#  {'image_id': 245846,
#   'split': 'train',
#   'sat_image_path': 'train/245846_sat.jpg',
#   'mask_path': 'train/245846_mask.png'},
#  {'image_id': 246378,
#   'split': 'train',
#   'sat_image_path': 'train/246378_sat.jpg',
#   'mask_path': 'train/246378_mask.png'},
#  {'image_id': 247179,
#   'split': 'train',
#   'sat_image_path': 'train/247179_sat.jpg',
#   'mask_path': 'train/247179_mask.png'},
#  {'image_id': 24813,
#   'split': 'train',
#   'sat_image_path': 'train/24813_sat.jpg',
#   'mask_path': 'train/24813_mask.png'},
#  {'image_id': 252743,
#   'split': 'train',
#   'sat_image_path': 'train/252743_sat.jpg',
#   'mask_path': 'train/252743_mask.png'},
#  {'image_id': 253691,
#   'split': 'train',
#   'sat_image_path': 'train/253691_sat.jpg',
#   'mask_path': 'train/253691_mask.png'},
#  {'image_id': 254565,
#   'split': 'train',
#   'sat_image_path': 'train/254565_sat.jpg',
#   'mask_path': 'train/254565_mask.png'},
#  {'image_id': 255711,
#   'split': 'train',
#   'sat_image_path': 'train/255711_sat.jpg',
#   'mask_path': 'train/255711_mask.png'},
#  {'image_id': 255876,
#   'split': 'train',
#   'sat_image_path': 'train/255876_sat.jpg',
#   'mask_path': 'train/255876_mask.png'},
#  {'image_id': 255889,
#   'split': 'train',
#   'sat_image_path': 'train/255889_sat.jpg',
#   'mask_path': 'train/255889_mask.png'},
#  {'image_id': 256189,
#   'split': 'train',
#   'sat_image_path': 'train/256189_sat.jpg',
#   'mask_path': 'train/256189_mask.png'},
#  {'image_id': 257695,
#   'split': 'train',
#   'sat_image_path': 'train/257695_sat.jpg',
#   'mask_path': 'train/257695_mask.png'},
#  {'image_id': 26261,
#   'split': 'train',
#   'sat_image_path': 'train/26261_sat.jpg',
#   'mask_path': 'train/26261_mask.png'},
#  {'image_id': 262885,
#   'split': 'train',
#   'sat_image_path': 'train/262885_sat.jpg',
#   'mask_path': 'train/262885_mask.png'},
#  {'image_id': 263576,
#   'split': 'train',
#   'sat_image_path': 'train/263576_sat.jpg',
#   'mask_path': 'train/263576_mask.png'},
#  {'image_id': 264436,
#   'split': 'train',
#   'sat_image_path': 'train/264436_sat.jpg',
#   'mask_path': 'train/264436_mask.png'},
#  {'image_id': 266,
#   'split': 'train',
#   'sat_image_path': 'train/266_sat.jpg',
#   'mask_path': 'train/266_mask.png'},
#  {'image_id': 267065,
#   'split': 'train',
#   'sat_image_path': 'train/267065_sat.jpg',
#   'mask_path': 'train/267065_mask.png'},
#  {'image_id': 267163,
#   'split': 'train',
#   'sat_image_path': 'train/267163_sat.jpg',
#   'mask_path': 'train/267163_mask.png'},
#  {'image_id': 268881,
#   'split': 'train',
#   'sat_image_path': 'train/268881_sat.jpg',
#   'mask_path': 'train/268881_mask.png'},
#  {'image_id': 269601,
#   'split': 'train',
#   'sat_image_path': 'train/269601_sat.jpg',
#   'mask_path': 'train/269601_mask.png'},
#  {'image_id': 271245,
#   'split': 'train',
#   'sat_image_path': 'train/271245_sat.jpg',
#   'mask_path': 'train/271245_mask.png'},
#  {'image_id': 271609,
#   'split': 'train',
#   'sat_image_path': 'train/271609_sat.jpg',
#   'mask_path': 'train/271609_mask.png'},
#  {'image_id': 271941,
#   'split': 'train',
#   'sat_image_path': 'train/271941_sat.jpg',
#   'mask_path': 'train/271941_mask.png'},
#  {'image_id': 273002,
#   'split': 'train',
#   'sat_image_path': 'train/273002_sat.jpg',
#   'mask_path': 'train/273002_mask.png'},
#  {'image_id': 273274,
#   'split': 'train',
#   'sat_image_path': 'train/273274_sat.jpg',
#   'mask_path': 'train/273274_mask.png'},
#  {'image_id': 27460,
#   'split': 'train',
#   'sat_image_path': 'train/27460_sat.jpg',
#   'mask_path': 'train/27460_mask.png'},
#  {'image_id': 276761,
#   'split': 'train',
#   'sat_image_path': 'train/276761_sat.jpg',
#   'mask_path': 'train/276761_mask.png'},
#  {'image_id': 276912,
#   'split': 'train',
#   'sat_image_path': 'train/276912_sat.jpg',
#   'mask_path': 'train/276912_mask.png'},
#  {'image_id': 277049,
#   'split': 'train',
#   'sat_image_path': 'train/277049_sat.jpg',
#   'mask_path': 'train/277049_mask.png'},
#  {'image_id': 2774,
#   'split': 'train',
#   'sat_image_path': 'train/2774_sat.jpg',
#   'mask_path': 'train/2774_mask.png'},
#  {'image_id': 277644,
#   'split': 'train',
#   'sat_image_path': 'train/277644_sat.jpg',
#   'mask_path': 'train/277644_mask.png'},
#  {'image_id': 277900,
#   'split': 'train',
#   'sat_image_path': 'train/277900_sat.jpg',
#   'mask_path': 'train/277900_mask.png'},
#  {'image_id': 277994,
#   'split': 'train',
#   'sat_image_path': 'train/277994_sat.jpg',
#   'mask_path': 'train/277994_mask.png'},
#  {'image_id': 280703,
#   'split': 'train',
#   'sat_image_path': 'train/280703_sat.jpg',
#   'mask_path': 'train/280703_mask.png'},
#  {'image_id': 280861,
#   'split': 'train',
#   'sat_image_path': 'train/280861_sat.jpg',
#   'mask_path': 'train/280861_mask.png'},
#  {'image_id': 282120,
#   'split': 'train',
#   'sat_image_path': 'train/282120_sat.jpg',
#   'mask_path': 'train/282120_mask.png'},
#  {'image_id': 283326,
#   'split': 'train',
#   'sat_image_path': 'train/283326_sat.jpg',
#   'mask_path': 'train/283326_mask.png'},
#  {'image_id': 28559,
#   'split': 'train',
#   'sat_image_path': 'train/28559_sat.jpg',
#   'mask_path': 'train/28559_mask.png'},
#  {'image_id': 286339,
#   'split': 'train',
#   'sat_image_path': 'train/286339_sat.jpg',
#   'mask_path': 'train/286339_mask.png'},
#  {'image_id': 28689,
#   'split': 'train',
#   'sat_image_path': 'train/28689_sat.jpg',
#   'mask_path': 'train/28689_mask.png'},
#  {'image_id': 28935,
#   'split': 'train',
#   'sat_image_path': 'train/28935_sat.jpg',
#   'mask_path': 'train/28935_mask.png'},
#  {'image_id': 291214,
#   'split': 'train',
#   'sat_image_path': 'train/291214_sat.jpg',
#   'mask_path': 'train/291214_mask.png'},
#  {'image_id': 291781,
#   'split': 'train',
#   'sat_image_path': 'train/291781_sat.jpg',
#   'mask_path': 'train/291781_mask.png'},
#  {'image_id': 293776,
#   'split': 'train',
#   'sat_image_path': 'train/293776_sat.jpg',
#   'mask_path': 'train/293776_mask.png'},
#  {'image_id': 29419,
#   'split': 'train',
#   'sat_image_path': 'train/29419_sat.jpg',
#   'mask_path': 'train/29419_mask.png'},
#  {'image_id': 294697,
#   'split': 'train',
#   'sat_image_path': 'train/294697_sat.jpg',
#   'mask_path': 'train/294697_mask.png'},
#  {'image_id': 294978,
#   'split': 'train',
#   'sat_image_path': 'train/294978_sat.jpg',
#   'mask_path': 'train/294978_mask.png'},
#  {'image_id': 296279,
#   'split': 'train',
#   'sat_image_path': 'train/296279_sat.jpg',
#   'mask_path': 'train/296279_mask.png'},
#  {'image_id': 296368,
#   'split': 'train',
#   'sat_image_path': 'train/296368_sat.jpg',
#   'mask_path': 'train/296368_mask.png'},
#  {'image_id': 298396,
#   'split': 'train',
#   'sat_image_path': 'train/298396_sat.jpg',
#   'mask_path': 'train/298396_mask.png'},
#  {'image_id': 298817,
#   'split': 'train',
#   'sat_image_path': 'train/298817_sat.jpg',
#   'mask_path': 'train/298817_mask.png'},
#  {'image_id': 299287,
#   'split': 'train',
#   'sat_image_path': 'train/299287_sat.jpg',
#   'mask_path': 'train/299287_mask.png'},
#  {'image_id': 300626,
#   'split': 'train',
#   'sat_image_path': 'train/300626_sat.jpg',
#   'mask_path': 'train/300626_mask.png'},
#  {'image_id': 300745,
#   'split': 'train',
#   'sat_image_path': 'train/300745_sat.jpg',
#   'mask_path': 'train/300745_mask.png'},
#  {'image_id': 300967,
#   'split': 'train',
#   'sat_image_path': 'train/300967_sat.jpg',
#   'mask_path': 'train/300967_mask.png'},
#  {'image_id': 303327,
#   'split': 'train',
#   'sat_image_path': 'train/303327_sat.jpg',
#   'mask_path': 'train/303327_mask.png'},
#  {'image_id': 306486,
#   'split': 'train',
#   'sat_image_path': 'train/306486_sat.jpg',
#   'mask_path': 'train/306486_mask.png'},
#  {'image_id': 307626,
#   'split': 'train',
#   'sat_image_path': 'train/307626_sat.jpg',
#   'mask_path': 'train/307626_mask.png'},
#  {'image_id': 308959,
#   'split': 'train',
#   'sat_image_path': 'train/308959_sat.jpg',
#   'mask_path': 'train/308959_mask.png'},
#  {'image_id': 309818,
#   'split': 'train',
#   'sat_image_path': 'train/309818_sat.jpg',
#   'mask_path': 'train/309818_mask.png'},
#  {'image_id': 310419,
#   'split': 'train',
#   'sat_image_path': 'train/310419_sat.jpg',
#   'mask_path': 'train/310419_mask.png'},
#  {'image_id': 311386,
#   'split': 'train',
#   'sat_image_path': 'train/311386_sat.jpg',
#   'mask_path': 'train/311386_mask.png'},
#  {'image_id': 312676,
#   'split': 'train',
#   'sat_image_path': 'train/312676_sat.jpg',
#   'mask_path': 'train/312676_mask.png'},
#  {'image_id': 315352,
#   'split': 'train',
#   'sat_image_path': 'train/315352_sat.jpg',
#   'mask_path': 'train/315352_mask.png'},
#  {'image_id': 315848,
#   'split': 'train',
#   'sat_image_path': 'train/315848_sat.jpg',
#   'mask_path': 'train/315848_mask.png'},
#  {'image_id': 316446,
#   'split': 'train',
#   'sat_image_path': 'train/316446_sat.jpg',
#   'mask_path': 'train/316446_mask.png'},
#  {'image_id': 318338,
#   'split': 'train',
#   'sat_image_path': 'train/318338_sat.jpg',
#   'mask_path': 'train/318338_mask.png'},
#  {'image_id': 321711,
#   'split': 'train',
#   'sat_image_path': 'train/321711_sat.jpg',
#   'mask_path': 'train/321711_mask.png'},
#  {'image_id': 321724,
#   'split': 'train',
#   'sat_image_path': 'train/321724_sat.jpg',
#   'mask_path': 'train/321724_mask.png'},
#  {'image_id': 322400,
#   'split': 'train',
#   'sat_image_path': 'train/322400_sat.jpg',
#   'mask_path': 'train/322400_mask.png'},
#  {'image_id': 323581,
#   'split': 'train',
#   'sat_image_path': 'train/323581_sat.jpg',
#   'mask_path': 'train/323581_mask.png'},
#  {'image_id': 324170,
#   'split': 'train',
#   'sat_image_path': 'train/324170_sat.jpg',
#   'mask_path': 'train/324170_mask.png'},
#  {'image_id': 325354,
#   'split': 'train',
#   'sat_image_path': 'train/325354_sat.jpg',
#   'mask_path': 'train/325354_mask.png'},
#  {'image_id': 326173,
#   'split': 'train',
#   'sat_image_path': 'train/326173_sat.jpg',
#   'mask_path': 'train/326173_mask.png'},
#  {'image_id': 326238,
#   'split': 'train',
#   'sat_image_path': 'train/326238_sat.jpg',
#   'mask_path': 'train/326238_mask.png'},
#  {'image_id': 329017,
#   'split': 'train',
#   'sat_image_path': 'train/329017_sat.jpg',
#   'mask_path': 'train/329017_mask.png'},
#  {'image_id': 330838,
#   'split': 'train',
#   'sat_image_path': 'train/330838_sat.jpg',
#   'mask_path': 'train/330838_mask.png'},
#  {'image_id': 331421,
#   'split': 'train',
#   'sat_image_path': 'train/331421_sat.jpg',
#   'mask_path': 'train/331421_mask.png'},
#  {'image_id': 331533,
#   'split': 'train',
#   'sat_image_path': 'train/331533_sat.jpg',
#   'mask_path': 'train/331533_mask.png'},
#  {'image_id': 331994,
#   'split': 'train',
#   'sat_image_path': 'train/331994_sat.jpg',
#   'mask_path': 'train/331994_mask.png'},
#  {'image_id': 332354,
#   'split': 'train',
#   'sat_image_path': 'train/332354_sat.jpg',
#   'mask_path': 'train/332354_mask.png'},
#  {'image_id': 33262,
#   'split': 'train',
#   'sat_image_path': 'train/33262_sat.jpg',
#   'mask_path': 'train/33262_mask.png'},
#  {'image_id': 333661,
#   'split': 'train',
#   'sat_image_path': 'train/333661_sat.jpg',
#   'mask_path': 'train/333661_mask.png'},
#  {'image_id': 334677,
#   'split': 'train',
#   'sat_image_path': 'train/334677_sat.jpg',
#   'mask_path': 'train/334677_mask.png'},
#  {'image_id': 334811,
#   'split': 'train',
#   'sat_image_path': 'train/334811_sat.jpg',
#   'mask_path': 'train/334811_mask.png'},
#  {'image_id': 335737,
#   'split': 'train',
#   'sat_image_path': 'train/335737_sat.jpg',
#   'mask_path': 'train/335737_mask.png'},
#  {'image_id': 33573,
#   'split': 'train',
#   'sat_image_path': 'train/33573_sat.jpg',
#   'mask_path': 'train/33573_mask.png'},
#  {'image_id': 337272,
#   'split': 'train',
#   'sat_image_path': 'train/337272_sat.jpg',
#   'mask_path': 'train/337272_mask.png'},
#  {'image_id': 338111,
#   'split': 'train',
#   'sat_image_path': 'train/338111_sat.jpg',
#   'mask_path': 'train/338111_mask.png'},
#  {'image_id': 338661,
#   'split': 'train',
#   'sat_image_path': 'train/338661_sat.jpg',
#   'mask_path': 'train/338661_mask.png'},
#  {'image_id': 338798,
#   'split': 'train',
#   'sat_image_path': 'train/338798_sat.jpg',
#   'mask_path': 'train/338798_mask.png'},
#  {'image_id': 340798,
#   'split': 'train',
#   'sat_image_path': 'train/340798_sat.jpg',
#   'mask_path': 'train/340798_mask.png'},
#  {'image_id': 340898,
#   'split': 'train',
#   'sat_image_path': 'train/340898_sat.jpg',
#   'mask_path': 'train/340898_mask.png'},
#  {'image_id': 343016,
#   'split': 'train',
#   'sat_image_path': 'train/343016_sat.jpg',
#   'mask_path': 'train/343016_mask.png'},
#  {'image_id': 343215,
#   'split': 'train',
#   'sat_image_path': 'train/343215_sat.jpg',
#   'mask_path': 'train/343215_mask.png'},
#  {'image_id': 34330,
#   'split': 'train',
#   'sat_image_path': 'train/34330_sat.jpg',
#   'mask_path': 'train/34330_mask.png'},
#  {'image_id': 343425,
#   'split': 'train',
#   'sat_image_path': 'train/343425_sat.jpg',
#   'mask_path': 'train/343425_mask.png'},
#  {'image_id': 34359,
#   'split': 'train',
#   'sat_image_path': 'train/34359_sat.jpg',
#   'mask_path': 'train/34359_mask.png'},
#  {'image_id': 345134,
#   'split': 'train',
#   'sat_image_path': 'train/345134_sat.jpg',
#   'mask_path': 'train/345134_mask.png'},
#  {'image_id': 345494,
#   'split': 'train',
#   'sat_image_path': 'train/345494_sat.jpg',
#   'mask_path': 'train/345494_mask.png'},
#  {'image_id': 34567,
#   'split': 'train',
#   'sat_image_path': 'train/34567_sat.jpg',
#   'mask_path': 'train/34567_mask.png'},
#  {'image_id': 347676,
#   'split': 'train',
#   'sat_image_path': 'train/347676_sat.jpg',
#   'mask_path': 'train/347676_mask.png'},
#  {'image_id': 347725,
#   'split': 'train',
#   'sat_image_path': 'train/347725_sat.jpg',
#   'mask_path': 'train/347725_mask.png'},
#  {'image_id': 3484,
#   'split': 'train',
#   'sat_image_path': 'train/3484_sat.jpg',
#   'mask_path': 'train/3484_mask.png'},
#  {'image_id': 349442,
#   'split': 'train',
#   'sat_image_path': 'train/349442_sat.jpg',
#   'mask_path': 'train/349442_mask.png'},
#  {'image_id': 350033,
#   'split': 'train',
#   'sat_image_path': 'train/350033_sat.jpg',
#   'mask_path': 'train/350033_mask.png'},
#  {'image_id': 350328,
#   'split': 'train',
#   'sat_image_path': 'train/350328_sat.jpg',
#   'mask_path': 'train/350328_mask.png'},
#  {'image_id': 351228,
#   'split': 'train',
#   'sat_image_path': 'train/351228_sat.jpg',
#   'mask_path': 'train/351228_mask.png'},
#  {'image_id': 351271,
#   'split': 'train',
#   'sat_image_path': 'train/351271_sat.jpg',
#   'mask_path': 'train/351271_mask.png'},
#  {'image_id': 351727,
#   'split': 'train',
#   'sat_image_path': 'train/351727_sat.jpg',
#   'mask_path': 'train/351727_mask.png'},
#  {'image_id': 352808,
#   'split': 'train',
#   'sat_image_path': 'train/352808_sat.jpg',
#   'mask_path': 'train/352808_mask.png'},
#  {'image_id': 354033,
#   'split': 'train',
#   'sat_image_path': 'train/354033_sat.jpg',
#   'mask_path': 'train/354033_mask.png'},
#  {'image_id': 358314,
#   'split': 'train',
#   'sat_image_path': 'train/358314_sat.jpg',
#   'mask_path': 'train/358314_mask.png'},
#  {'image_id': 358464,
#   'split': 'train',
#   'sat_image_path': 'train/358464_sat.jpg',
#   'mask_path': 'train/358464_mask.png'},
#  {'image_id': 358591,
#   'split': 'train',
#   'sat_image_path': 'train/358591_sat.jpg',
#   'mask_path': 'train/358591_mask.png'},
#  {'image_id': 361129,
#   'split': 'train',
#   'sat_image_path': 'train/361129_sat.jpg',
#   'mask_path': 'train/361129_mask.png'},
#  {'image_id': 36183,
#   'split': 'train',
#   'sat_image_path': 'train/36183_sat.jpg',
#   'mask_path': 'train/36183_mask.png'},
#  {'image_id': 362191,
#   'split': 'train',
#   'sat_image_path': 'train/362191_sat.jpg',
#   'mask_path': 'train/362191_mask.png'},
#  {'image_id': 362274,
#   'split': 'train',
#   'sat_image_path': 'train/362274_sat.jpg',
#   'mask_path': 'train/362274_mask.png'},
#  {'image_id': 365555,
#   'split': 'train',
#   'sat_image_path': 'train/365555_sat.jpg',
#   'mask_path': 'train/365555_mask.png'},
#  {'image_id': 373103,
#   'split': 'train',
#   'sat_image_path': 'train/373103_sat.jpg',
#   'mask_path': 'train/373103_mask.png'},
#  {'image_id': 373186,
#   'split': 'train',
#   'sat_image_path': 'train/373186_sat.jpg',
#   'mask_path': 'train/373186_mask.png'},
#  {'image_id': 375563,
#   'split': 'train',
#   'sat_image_path': 'train/375563_sat.jpg',
#   'mask_path': 'train/375563_mask.png'},
#  {'image_id': 37586,
#   'split': 'train',
#   'sat_image_path': 'train/37586_sat.jpg',
#   'mask_path': 'train/37586_mask.png'},
#  {'image_id': 376441,
#   'split': 'train',
#   'sat_image_path': 'train/376441_sat.jpg',
#   'mask_path': 'train/376441_mask.png'},
#  {'image_id': 37755,
#   'split': 'train',
#   'sat_image_path': 'train/37755_sat.jpg',
#   'mask_path': 'train/37755_mask.png'},
#  {'image_id': 382428,
#   'split': 'train',
#   'sat_image_path': 'train/382428_sat.jpg',
#   'mask_path': 'train/382428_mask.png'},
#  {'image_id': 383392,
#   'split': 'train',
#   'sat_image_path': 'train/383392_sat.jpg',
#   'mask_path': 'train/383392_mask.png'},
#  {'image_id': 383637,
#   'split': 'train',
#   'sat_image_path': 'train/383637_sat.jpg',
#   'mask_path': 'train/383637_mask.png'},
#  {'image_id': 384477,
#   'split': 'train',
#   'sat_image_path': 'train/384477_sat.jpg',
#   'mask_path': 'train/384477_mask.png'},
#  {'image_id': 387018,
#   'split': 'train',
#   'sat_image_path': 'train/387018_sat.jpg',
#   'mask_path': 'train/387018_mask.png'},
#  {'image_id': 387554,
#   'split': 'train',
#   'sat_image_path': 'train/387554_sat.jpg',
#   'mask_path': 'train/387554_mask.png'},
#  {'image_id': 388811,
#   'split': 'train',
#   'sat_image_path': 'train/388811_sat.jpg',
#   'mask_path': 'train/388811_mask.png'},
#  {'image_id': 392711,
#   'split': 'train',
#   'sat_image_path': 'train/392711_sat.jpg',
#   'mask_path': 'train/392711_mask.png'},
#  {'image_id': 393043,
#   'split': 'train',
#   'sat_image_path': 'train/393043_sat.jpg',
#   'mask_path': 'train/393043_mask.png'},
#  {'image_id': 394500,
#   'split': 'train',
#   'sat_image_path': 'train/394500_sat.jpg',
#   'mask_path': 'train/394500_mask.png'},
#  {'image_id': 396979,
#   'split': 'train',
#   'sat_image_path': 'train/396979_sat.jpg',
#   'mask_path': 'train/396979_mask.png'},
#  {'image_id': 397137,
#   'split': 'train',
#   'sat_image_path': 'train/397137_sat.jpg',
#   'mask_path': 'train/397137_mask.png'},
#  {'image_id': 397351,
#   'split': 'train',
#   'sat_image_path': 'train/397351_sat.jpg',
#   'mask_path': 'train/397351_mask.png'},
#  {'image_id': 397864,
#   'split': 'train',
#   'sat_image_path': 'train/397864_sat.jpg',
#   'mask_path': 'train/397864_mask.png'},
#  {'image_id': 400179,
#   'split': 'train',
#   'sat_image_path': 'train/400179_sat.jpg',
#   'mask_path': 'train/400179_mask.png'},
#  {'image_id': 40168,
#   'split': 'train',
#   'sat_image_path': 'train/40168_sat.jpg',
#   'mask_path': 'train/40168_mask.png'},
#  {'image_id': 402002,
#   'split': 'train',
#   'sat_image_path': 'train/402002_sat.jpg',
#   'mask_path': 'train/402002_mask.png'},
#  {'image_id': 402209,
#   'split': 'train',
#   'sat_image_path': 'train/402209_sat.jpg',
#   'mask_path': 'train/402209_mask.png'},
#  {'image_id': 40350,
#   'split': 'train',
#   'sat_image_path': 'train/40350_sat.jpg',
#   'mask_path': 'train/40350_mask.png'},
#  {'image_id': 403978,
#   'split': 'train',
#   'sat_image_path': 'train/403978_sat.jpg',
#   'mask_path': 'train/403978_mask.png'},
#  {'image_id': 405378,
#   'split': 'train',
#   'sat_image_path': 'train/405378_sat.jpg',
#   'mask_path': 'train/405378_mask.png'},
#  {'image_id': 405744,
#   'split': 'train',
#   'sat_image_path': 'train/405744_sat.jpg',
#   'mask_path': 'train/405744_mask.png'},
#  {'image_id': 406425,
#   'split': 'train',
#   'sat_image_path': 'train/406425_sat.jpg',
#   'mask_path': 'train/406425_mask.png'},
#  {'image_id': 407467,
#   'split': 'train',
#   'sat_image_path': 'train/407467_sat.jpg',
#   'mask_path': 'train/407467_mask.png'},
#  {'image_id': 411741,
#   'split': 'train',
#   'sat_image_path': 'train/411741_sat.jpg',
#   'mask_path': 'train/411741_mask.png'},
#  {'image_id': 412210,
#   'split': 'train',
#   'sat_image_path': 'train/412210_sat.jpg',
#   'mask_path': 'train/412210_mask.png'},
#  {'image_id': 413779,
#   'split': 'train',
#   'sat_image_path': 'train/413779_sat.jpg',
#   'mask_path': 'train/413779_mask.png'},
#  {'image_id': 416381,
#   'split': 'train',
#   'sat_image_path': 'train/416381_sat.jpg',
#   'mask_path': 'train/416381_mask.png'},
#  {'image_id': 416463,
#   'split': 'train',
#   'sat_image_path': 'train/416463_sat.jpg',
#   'mask_path': 'train/416463_mask.png'},
#  {'image_id': 416794,
#   'split': 'train',
#   'sat_image_path': 'train/416794_sat.jpg',
#   'mask_path': 'train/416794_mask.png'},
#  {'image_id': 417313,
#   'split': 'train',
#   'sat_image_path': 'train/417313_sat.jpg',
#   'mask_path': 'train/417313_mask.png'},
#  {'image_id': 418261,
#   'split': 'train',
#   'sat_image_path': 'train/418261_sat.jpg',
#   'mask_path': 'train/418261_mask.png'},
#  {'image_id': 41944,
#   'split': 'train',
#   'sat_image_path': 'train/41944_sat.jpg',
#   'mask_path': 'train/41944_mask.png'},
#  {'image_id': 419820,
#   'split': 'train',
#   'sat_image_path': 'train/419820_sat.jpg',
#   'mask_path': 'train/419820_mask.png'},
#  {'image_id': 420066,
#   'split': 'train',
#   'sat_image_path': 'train/420066_sat.jpg',
#   'mask_path': 'train/420066_mask.png'},
#  {'image_id': 420078,
#   'split': 'train',
#   'sat_image_path': 'train/420078_sat.jpg',
#   'mask_path': 'train/420078_mask.png'},
#  {'image_id': 423117,
#   'split': 'train',
#   'sat_image_path': 'train/423117_sat.jpg',
#   'mask_path': 'train/423117_mask.png'},
#  {'image_id': 424590,
#   'split': 'train',
#   'sat_image_path': 'train/424590_sat.jpg',
#   'mask_path': 'train/424590_mask.png'},
#  {'image_id': 427037,
#   'split': 'train',
#   'sat_image_path': 'train/427037_sat.jpg',
#   'mask_path': 'train/427037_mask.png'},
#  {'image_id': 427774,
#   'split': 'train',
#   'sat_image_path': 'train/427774_sat.jpg',
#   'mask_path': 'train/427774_mask.png'},
#  {'image_id': 428327,
#   'split': 'train',
#   'sat_image_path': 'train/428327_sat.jpg',
#   'mask_path': 'train/428327_mask.png'},
#  {'image_id': 428597,
#   'split': 'train',
#   'sat_image_path': 'train/428597_sat.jpg',
#   'mask_path': 'train/428597_mask.png'},
#  {'image_id': 428841,
#   'split': 'train',
#   'sat_image_path': 'train/428841_sat.jpg',
#   'mask_path': 'train/428841_mask.png'},
#  {'image_id': 430587,
#   'split': 'train',
#   'sat_image_path': 'train/430587_sat.jpg',
#   'mask_path': 'train/430587_mask.png'},
#  {'image_id': 432089,
#   'split': 'train',
#   'sat_image_path': 'train/432089_sat.jpg',
#   'mask_path': 'train/432089_mask.png'},
#  {'image_id': 434210,
#   'split': 'train',
#   'sat_image_path': 'train/434210_sat.jpg',
#   'mask_path': 'train/434210_mask.png'},
#  {'image_id': 434243,
#   'split': 'train',
#   'sat_image_path': 'train/434243_sat.jpg',
#   'mask_path': 'train/434243_mask.png'},
#  {'image_id': 435277,
#   'split': 'train',
#   'sat_image_path': 'train/435277_sat.jpg',
#   'mask_path': 'train/435277_mask.png'},
#  {'image_id': 437963,
#   'split': 'train',
#   'sat_image_path': 'train/437963_sat.jpg',
#   'mask_path': 'train/437963_mask.png'},
#  {'image_id': 43814,
#   'split': 'train',
#   'sat_image_path': 'train/43814_sat.jpg',
#   'mask_path': 'train/43814_mask.png'},
#  {'image_id': 438721,
#   'split': 'train',
#   'sat_image_path': 'train/438721_sat.jpg',
#   'mask_path': 'train/438721_mask.png'},
#  {'image_id': 439854,
#   'split': 'train',
#   'sat_image_path': 'train/439854_sat.jpg',
#   'mask_path': 'train/439854_mask.png'},
#  {'image_id': 44070,
#   'split': 'train',
#   'sat_image_path': 'train/44070_sat.jpg',
#   'mask_path': 'train/44070_mask.png'},
#  {'image_id': 442329,
#   'split': 'train',
#   'sat_image_path': 'train/442329_sat.jpg',
#   'mask_path': 'train/442329_mask.png'},
#  {'image_id': 442338,
#   'split': 'train',
#   'sat_image_path': 'train/442338_sat.jpg',
#   'mask_path': 'train/442338_mask.png'},
#  {'image_id': 443271,
#   'split': 'train',
#   'sat_image_path': 'train/443271_sat.jpg',
#   'mask_path': 'train/443271_mask.png'},
#  {'image_id': 444902,
#   'split': 'train',
#   'sat_image_path': 'train/444902_sat.jpg',
#   'mask_path': 'train/444902_mask.png'},
#  {'image_id': 449319,
#   'split': 'train',
#   'sat_image_path': 'train/449319_sat.jpg',
#   'mask_path': 'train/449319_mask.png'},
#  {'image_id': 45357,
#   'split': 'train',
#   'sat_image_path': 'train/45357_sat.jpg',
#   'mask_path': 'train/45357_mask.png'},
#  {'image_id': 454655,
#   'split': 'train',
#   'sat_image_path': 'train/454655_sat.jpg',
#   'mask_path': 'train/454655_mask.png'},
#  {'image_id': 455374,
#   'split': 'train',
#   'sat_image_path': 'train/455374_sat.jpg',
#   'mask_path': 'train/455374_mask.png'},
#  {'image_id': 45676,
#   'split': 'train',
#   'sat_image_path': 'train/45676_sat.jpg',
#   'mask_path': 'train/45676_mask.png'},
#  {'image_id': 457070,
#   'split': 'train',
#   'sat_image_path': 'train/457070_sat.jpg',
#   'mask_path': 'train/457070_mask.png'},
#  {'image_id': 457265,
#   'split': 'train',
#   'sat_image_path': 'train/457265_sat.jpg',
#   'mask_path': 'train/457265_mask.png'},
#  {'image_id': 457982,
#   'split': 'train',
#   'sat_image_path': 'train/457982_sat.jpg',
#   'mask_path': 'train/457982_mask.png'},
#  {'image_id': 458687,
#   'split': 'train',
#   'sat_image_path': 'train/458687_sat.jpg',
#   'mask_path': 'train/458687_mask.png'},
#  {'image_id': 458776,
#   'split': 'train',
#   'sat_image_path': 'train/458776_sat.jpg',
#   'mask_path': 'train/458776_mask.png'},
#  {'image_id': 461001,
#   'split': 'train',
#   'sat_image_path': 'train/461001_sat.jpg',
#   'mask_path': 'train/461001_mask.png'},
#  {'image_id': 461755,
#   'split': 'train',
#   'sat_image_path': 'train/461755_sat.jpg',
#   'mask_path': 'train/461755_mask.png'},
#  {'image_id': 462612,
#   'split': 'train',
#   'sat_image_path': 'train/462612_sat.jpg',
#   'mask_path': 'train/462612_mask.png'},
#  {'image_id': 463855,
#   'split': 'train',
#   'sat_image_path': 'train/463855_sat.jpg',
#   'mask_path': 'train/463855_mask.png'},
#  {'image_id': 467076,
#   'split': 'train',
#   'sat_image_path': 'train/467076_sat.jpg',
#   'mask_path': 'train/467076_mask.png'},
#  {'image_id': 467855,
#   'split': 'train',
#   'sat_image_path': 'train/467855_sat.jpg',
#   'mask_path': 'train/467855_mask.png'},
#  {'image_id': 468103,
#   'split': 'train',
#   'sat_image_path': 'train/468103_sat.jpg',
#   'mask_path': 'train/468103_mask.png'},
#  {'image_id': 470446,
#   'split': 'train',
#   'sat_image_path': 'train/470446_sat.jpg',
#   'mask_path': 'train/470446_mask.png'},
#  {'image_id': 470798,
#   'split': 'train',
#   'sat_image_path': 'train/470798_sat.jpg',
#   'mask_path': 'train/470798_mask.png'},
#  {'image_id': 471187,
#   'split': 'train',
#   'sat_image_path': 'train/471187_sat.jpg',
#   'mask_path': 'train/471187_mask.png'},
#  {'image_id': 471930,
#   'split': 'train',
#   'sat_image_path': 'train/471930_sat.jpg',
#   'mask_path': 'train/471930_mask.png'},
#  {'image_id': 472774,
#   'split': 'train',
#   'sat_image_path': 'train/472774_sat.jpg',
#   'mask_path': 'train/472774_mask.png'},
#  {'image_id': 476582,
#   'split': 'train',
#   'sat_image_path': 'train/476582_sat.jpg',
#   'mask_path': 'train/476582_mask.png'},
#  {'image_id': 476991,
#   'split': 'train',
#   'sat_image_path': 'train/476991_sat.jpg',
#   'mask_path': 'train/476991_mask.png'},
#  {'image_id': 479682,
#   'split': 'train',
#   'sat_image_path': 'train/479682_sat.jpg',
#   'mask_path': 'train/479682_mask.png'},
#  {'image_id': 482365,
#   'split': 'train',
#   'sat_image_path': 'train/482365_sat.jpg',
#   'mask_path': 'train/482365_mask.png'},
#  {'image_id': 483506,
#   'split': 'train',
#   'sat_image_path': 'train/483506_sat.jpg',
#   'mask_path': 'train/483506_mask.png'},
#  {'image_id': 485061,
#   'split': 'train',
#   'sat_image_path': 'train/485061_sat.jpg',
#   'mask_path': 'train/485061_mask.png'},
#  {'image_id': 491356,
#   'split': 'train',
#   'sat_image_path': 'train/491356_sat.jpg',
#   'mask_path': 'train/491356_mask.png'},
#  {'image_id': 491491,
#   'split': 'train',
#   'sat_image_path': 'train/491491_sat.jpg',
#   'mask_path': 'train/491491_mask.png'},
#  {'image_id': 491696,
#   'split': 'train',
#   'sat_image_path': 'train/491696_sat.jpg',
#   'mask_path': 'train/491696_mask.png'},
#  {'image_id': 492365,
#   'split': 'train',
#   'sat_image_path': 'train/492365_sat.jpg',
#   'mask_path': 'train/492365_mask.png'},
#  {'image_id': 495406,
#   'split': 'train',
#   'sat_image_path': 'train/495406_sat.jpg',
#   'mask_path': 'train/495406_mask.png'},
#  {'image_id': 495876,
#   'split': 'train',
#   'sat_image_path': 'train/495876_sat.jpg',
#   'mask_path': 'train/495876_mask.png'},
#  {'image_id': 496948,
#   'split': 'train',
#   'sat_image_path': 'train/496948_sat.jpg',
#   'mask_path': 'train/496948_mask.png'},
#  {'image_id': 498049,
#   'split': 'train',
#   'sat_image_path': 'train/498049_sat.jpg',
#   'mask_path': 'train/498049_mask.png'},
#  {'image_id': 499161,
#   'split': 'train',
#   'sat_image_path': 'train/499161_sat.jpg',
#   'mask_path': 'train/499161_mask.png'},
#  {'image_id': 499266,
#   'split': 'train',
#   'sat_image_path': 'train/499266_sat.jpg',
#   'mask_path': 'train/499266_mask.png'},
#  {'image_id': 499325,
#   'split': 'train',
#   'sat_image_path': 'train/499325_sat.jpg',
#   'mask_path': 'train/499325_mask.png'},
#  {'image_id': 499418,
#   'split': 'train',
#   'sat_image_path': 'train/499418_sat.jpg',
#   'mask_path': 'train/499418_mask.png'},
#  {'image_id': 499511,
#   'split': 'train',
#   'sat_image_path': 'train/499511_sat.jpg',
#   'mask_path': 'train/499511_mask.png'},
#  {'image_id': 499600,
#   'split': 'train',
#   'sat_image_path': 'train/499600_sat.jpg',
#   'mask_path': 'train/499600_mask.png'},
#  {'image_id': 501053,
#   'split': 'train',
#   'sat_image_path': 'train/501053_sat.jpg',
#   'mask_path': 'train/501053_mask.png'},
#  {'image_id': 501284,
#   'split': 'train',
#   'sat_image_path': 'train/501284_sat.jpg',
#   'mask_path': 'train/501284_mask.png'},
#  {'image_id': 501804,
#   'split': 'train',
#   'sat_image_path': 'train/501804_sat.jpg',
#   'mask_path': 'train/501804_mask.png'},
#  {'image_id': 503968,
#   'split': 'train',
#   'sat_image_path': 'train/503968_sat.jpg',
#   'mask_path': 'train/503968_mask.png'},
#  {'image_id': 504704,
#   'split': 'train',
#   'sat_image_path': 'train/504704_sat.jpg',
#   'mask_path': 'train/504704_mask.png'},
#  {'image_id': 505217,
#   'split': 'train',
#   'sat_image_path': 'train/505217_sat.jpg',
#   'mask_path': 'train/505217_mask.png'},
#  {'image_id': 507241,
#   'split': 'train',
#   'sat_image_path': 'train/507241_sat.jpg',
#   'mask_path': 'train/507241_mask.png'},
#  {'image_id': 508571,
#   'split': 'train',
#   'sat_image_path': 'train/508571_sat.jpg',
#   'mask_path': 'train/508571_mask.png'},
#  {'image_id': 508676,
#   'split': 'train',
#   'sat_image_path': 'train/508676_sat.jpg',
#   'mask_path': 'train/508676_mask.png'},
#  {'image_id': 509290,
#   'split': 'train',
#   'sat_image_path': 'train/509290_sat.jpg',
#   'mask_path': 'train/509290_mask.png'},
#  {'image_id': 511850,
#   'split': 'train',
#   'sat_image_path': 'train/511850_sat.jpg',
#   'mask_path': 'train/511850_mask.png'},
#  {'image_id': 512669,
#   'split': 'train',
#   'sat_image_path': 'train/512669_sat.jpg',
#   'mask_path': 'train/512669_mask.png'},
#  {'image_id': 513585,
#   'split': 'train',
#   'sat_image_path': 'train/513585_sat.jpg',
#   'mask_path': 'train/513585_mask.png'},
#  {'image_id': 513968,
#   'split': 'train',
#   'sat_image_path': 'train/513968_sat.jpg',
#   'mask_path': 'train/513968_mask.png'},
#  {'image_id': 514385,
#   'split': 'train',
#   'sat_image_path': 'train/514385_sat.jpg',
#   'mask_path': 'train/514385_mask.png'},
#  {'image_id': 514414,
#   'split': 'train',
#   'sat_image_path': 'train/514414_sat.jpg',
#   'mask_path': 'train/514414_mask.png'},
#  {'image_id': 515521,
#   'split': 'train',
#   'sat_image_path': 'train/515521_sat.jpg',
#   'mask_path': 'train/515521_mask.png'},
#  {'image_id': 516056,
#   'split': 'train',
#   'sat_image_path': 'train/516056_sat.jpg',
#   'mask_path': 'train/516056_mask.png'},
#  {'image_id': 516317,
#   'split': 'train',
#   'sat_image_path': 'train/516317_sat.jpg',
#   'mask_path': 'train/516317_mask.png'},
#  {'image_id': 518833,
#   'split': 'train',
#   'sat_image_path': 'train/518833_sat.jpg',
#   'mask_path': 'train/518833_mask.png'},
#  {'image_id': 51911,
#   'split': 'train',
#   'sat_image_path': 'train/51911_sat.jpg',
#   'mask_path': 'train/51911_mask.png'},
#  {'image_id': 520614,
#   'split': 'train',
#   'sat_image_path': 'train/520614_sat.jpg',
#   'mask_path': 'train/520614_mask.png'},
#  {'image_id': 524056,
#   'split': 'train',
#   'sat_image_path': 'train/524056_sat.jpg',
#   'mask_path': 'train/524056_mask.png'},
#  {'image_id': 524518,
#   'split': 'train',
#   'sat_image_path': 'train/524518_sat.jpg',
#   'mask_path': 'train/524518_mask.png'},
#  {'image_id': 525105,
#   'split': 'train',
#   'sat_image_path': 'train/525105_sat.jpg',
#   'mask_path': 'train/525105_mask.png'},
# ...
#   'mask_path': nan},
#  {'image_id': 392604,
#   'split': 'valid',
#   'sat_image_path': 'valid/392604_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 393509,
#   'split': 'valid',
#   'sat_image_path': 'valid/393509_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 395400,
#   'split': 'valid',
#   'sat_image_path': 'valid/395400_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 409953,
#   'split': 'valid',
#   'sat_image_path': 'valid/409953_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 410949,
#   'split': 'valid',
#   'sat_image_path': 'valid/410949_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 411176,
#   'split': 'valid',
#   'sat_image_path': 'valid/411176_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 41687,
#   'split': 'valid',
#   'sat_image_path': 'valid/41687_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 421783,
#   'split': 'valid',
#   'sat_image_path': 'valid/421783_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 433903,
#   'split': 'valid',
#   'sat_image_path': 'valid/433903_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 442420,
#   'split': 'valid',
#   'sat_image_path': 'valid/442420_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 443525,
#   'split': 'valid',
#   'sat_image_path': 'valid/443525_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 448385,
#   'split': 'valid',
#   'sat_image_path': 'valid/448385_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 452469,
#   'split': 'valid',
#   'sat_image_path': 'valid/452469_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 456386,
#   'split': 'valid',
#   'sat_image_path': 'valid/456386_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 457244,
#   'split': 'valid',
#   'sat_image_path': 'valid/457244_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 461861,
#   'split': 'valid',
#   'sat_image_path': 'valid/461861_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 463976,
#   'split': 'valid',
#   'sat_image_path': 'valid/463976_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 470711,
#   'split': 'valid',
#   'sat_image_path': 'valid/470711_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 480616,
#   'split': 'valid',
#   'sat_image_path': 'valid/480616_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 482930,
#   'split': 'valid',
#   'sat_image_path': 'valid/482930_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 490706,
#   'split': 'valid',
#   'sat_image_path': 'valid/490706_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 492514,
#   'split': 'valid',
#   'sat_image_path': 'valid/492514_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 493398,
#   'split': 'valid',
#   'sat_image_path': 'valid/493398_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 496725,
#   'split': 'valid',
#   'sat_image_path': 'valid/496725_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 499932,
#   'split': 'valid',
#   'sat_image_path': 'valid/499932_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 501162,
#   'split': 'valid',
#   'sat_image_path': 'valid/501162_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 509523,
#   'split': 'valid',
#   'sat_image_path': 'valid/509523_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 512331,
#   'split': 'valid',
#   'sat_image_path': 'valid/512331_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 515578,
#   'split': 'valid',
#   'sat_image_path': 'valid/515578_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 519596,
#   'split': 'valid',
#   'sat_image_path': 'valid/519596_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 521804,
#   'split': 'valid',
#   'sat_image_path': 'valid/521804_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 525158,
#   'split': 'valid',
#   'sat_image_path': 'valid/525158_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 537140,
#   'split': 'valid',
#   'sat_image_path': 'valid/537140_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 538959,
#   'split': 'valid',
#   'sat_image_path': 'valid/538959_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 540125,
#   'split': 'valid',
#   'sat_image_path': 'valid/540125_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 541127,
#   'split': 'valid',
#   'sat_image_path': 'valid/541127_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 541237,
#   'split': 'valid',
#   'sat_image_path': 'valid/541237_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 543106,
#   'split': 'valid',
#   'sat_image_path': 'valid/543106_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 549550,
#   'split': 'valid',
#   'sat_image_path': 'valid/549550_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 550979,
#   'split': 'valid',
#   'sat_image_path': 'valid/550979_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 551291,
#   'split': 'valid',
#   'sat_image_path': 'valid/551291_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 553387,
#   'split': 'valid',
#   'sat_image_path': 'valid/553387_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 561221,
#   'split': 'valid',
#   'sat_image_path': 'valid/561221_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 565007,
#   'split': 'valid',
#   'sat_image_path': 'valid/565007_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 570277,
#   'split': 'valid',
#   'sat_image_path': 'valid/570277_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 57280,
#   'split': 'valid',
#   'sat_image_path': 'valid/57280_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 573103,
#   'split': 'valid',
#   'sat_image_path': 'valid/573103_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 579026,
#   'split': 'valid',
#   'sat_image_path': 'valid/579026_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 584805,
#   'split': 'valid',
#   'sat_image_path': 'valid/584805_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 58687,
#   'split': 'valid',
#   'sat_image_path': 'valid/58687_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 590876,
#   'split': 'valid',
#   'sat_image_path': 'valid/590876_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 597724,
#   'split': 'valid',
#   'sat_image_path': 'valid/597724_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 609620,
#   'split': 'valid',
#   'sat_image_path': 'valid/609620_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 621321,
#   'split': 'valid',
#   'sat_image_path': 'valid/621321_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 626585,
#   'split': 'valid',
#   'sat_image_path': 'valid/626585_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 628101,
#   'split': 'valid',
#   'sat_image_path': 'valid/628101_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 637614,
#   'split': 'valid',
#   'sat_image_path': 'valid/637614_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 647277,
#   'split': 'valid',
#   'sat_image_path': 'valid/647277_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 650401,
#   'split': 'valid',
#   'sat_image_path': 'valid/650401_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 650747,
#   'split': 'valid',
#   'sat_image_path': 'valid/650747_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 651633,
#   'split': 'valid',
#   'sat_image_path': 'valid/651633_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 667266,
#   'split': 'valid',
#   'sat_image_path': 'valid/667266_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 671274,
#   'split': 'valid',
#   'sat_image_path': 'valid/671274_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 6783,
#   'split': 'valid',
#   'sat_image_path': 'valid/6783_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 686345,
#   'split': 'valid',
#   'sat_image_path': 'valid/686345_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 687972,
#   'split': 'valid',
#   'sat_image_path': 'valid/687972_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 688045,
#   'split': 'valid',
#   'sat_image_path': 'valid/688045_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 69582,
#   'split': 'valid',
#   'sat_image_path': 'valid/69582_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 70587,
#   'split': 'valid',
#   'sat_image_path': 'valid/70587_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 706496,
#   'split': 'valid',
#   'sat_image_path': 'valid/706496_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 708789,
#   'split': 'valid',
#   'sat_image_path': 'valid/708789_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 70946,
#   'split': 'valid',
#   'sat_image_path': 'valid/70946_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 721337,
#   'split': 'valid',
#   'sat_image_path': 'valid/721337_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 739296,
#   'split': 'valid',
#   'sat_image_path': 'valid/739296_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 739567,
#   'split': 'valid',
#   'sat_image_path': 'valid/739567_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 740499,
#   'split': 'valid',
#   'sat_image_path': 'valid/740499_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 745310,
#   'split': 'valid',
#   'sat_image_path': 'valid/745310_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 758010,
#   'split': 'valid',
#   'sat_image_path': 'valid/758010_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 761391,
#   'split': 'valid',
#   'sat_image_path': 'valid/761391_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 76568,
#   'split': 'valid',
#   'sat_image_path': 'valid/76568_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 770447,
#   'split': 'valid',
#   'sat_image_path': 'valid/770447_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 782851,
#   'split': 'valid',
#   'sat_image_path': 'valid/782851_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 783813,
#   'split': 'valid',
#   'sat_image_path': 'valid/783813_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 784177,
#   'split': 'valid',
#   'sat_image_path': 'valid/784177_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 808681,
#   'split': 'valid',
#   'sat_image_path': 'valid/808681_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 812112,
#   'split': 'valid',
#   'sat_image_path': 'valid/812112_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 814739,
#   'split': 'valid',
#   'sat_image_path': 'valid/814739_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 823133,
#   'split': 'valid',
#   'sat_image_path': 'valid/823133_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 826290,
#   'split': 'valid',
#   'sat_image_path': 'valid/826290_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 827386,
#   'split': 'valid',
#   'sat_image_path': 'valid/827386_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 828590,
#   'split': 'valid',
#   'sat_image_path': 'valid/828590_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 8285,
#   'split': 'valid',
#   'sat_image_path': 'valid/8285_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 83235,
#   'split': 'valid',
#   'sat_image_path': 'valid/83235_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 84186,
#   'split': 'valid',
#   'sat_image_path': 'valid/84186_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 842772,
#   'split': 'valid',
#   'sat_image_path': 'valid/842772_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 846173,
#   'split': 'valid',
#   'sat_image_path': 'valid/846173_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 847543,
#   'split': 'valid',
#   'sat_image_path': 'valid/847543_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 851493,
#   'split': 'valid',
#   'sat_image_path': 'valid/851493_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 861233,
#   'split': 'valid',
#   'sat_image_path': 'valid/861233_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 867030,
#   'split': 'valid',
#   'sat_image_path': 'valid/867030_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 870832,
#   'split': 'valid',
#   'sat_image_path': 'valid/870832_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 878219,
#   'split': 'valid',
#   'sat_image_path': 'valid/878219_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 890141,
#   'split': 'valid',
#   'sat_image_path': 'valid/890141_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 890309,
#   'split': 'valid',
#   'sat_image_path': 'valid/890309_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 893619,
#   'split': 'valid',
#   'sat_image_path': 'valid/893619_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 895755,
#   'split': 'valid',
#   'sat_image_path': 'valid/895755_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 901585,
#   'split': 'valid',
#   'sat_image_path': 'valid/901585_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 905310,
#   'split': 'valid',
#   'sat_image_path': 'valid/905310_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 92653,
#   'split': 'valid',
#   'sat_image_path': 'valid/92653_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 929355,
#   'split': 'valid',
#   'sat_image_path': 'valid/929355_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 941920,
#   'split': 'valid',
#   'sat_image_path': 'valid/941920_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 943073,
#   'split': 'valid',
#   'sat_image_path': 'valid/943073_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 945482,
#   'split': 'valid',
#   'sat_image_path': 'valid/945482_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 952345,
#   'split': 'valid',
#   'sat_image_path': 'valid/952345_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 95483,
#   'split': 'valid',
#   'sat_image_path': 'valid/95483_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 957441,
#   'split': 'valid',
#   'sat_image_path': 'valid/957441_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 959556,
#   'split': 'valid',
#   'sat_image_path': 'valid/959556_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 965410,
#   'split': 'valid',
#   'sat_image_path': 'valid/965410_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 969557,
#   'split': 'valid',
#   'sat_image_path': 'valid/969557_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 972516,
#   'split': 'valid',
#   'sat_image_path': 'valid/972516_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 980625,
#   'split': 'valid',
#   'sat_image_path': 'valid/980625_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 984098,
#   'split': 'valid',
#   'sat_image_path': 'valid/984098_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 99299,
#   'split': 'valid',
#   'sat_image_path': 'valid/99299_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 998699,
#   'split': 'valid',
#   'sat_image_path': 'valid/998699_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 100877,
#   'split': 'test',
#   'sat_image_path': 'test/100877_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 103215,
#   'split': 'test',
#   'sat_image_path': 'test/103215_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 103742,
#   'split': 'test',
#   'sat_image_path': 'test/103742_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 110224,
#   'split': 'test',
#   'sat_image_path': 'test/110224_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 112946,
#   'split': 'test',
#   'sat_image_path': 'test/112946_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 114542,
#   'split': 'test',
#   'sat_image_path': 'test/114542_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 115800,
#   'split': 'test',
#   'sat_image_path': 'test/115800_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 118757,
#   'split': 'test',
#   'sat_image_path': 'test/118757_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 119896,
#   'split': 'test',
#   'sat_image_path': 'test/119896_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 120939,
#   'split': 'test',
#   'sat_image_path': 'test/120939_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 121151,
#   'split': 'test',
#   'sat_image_path': 'test/121151_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 123976,
#   'split': 'test',
#   'sat_image_path': 'test/123976_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 125014,
#   'split': 'test',
#   'sat_image_path': 'test/125014_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 133160,
#   'split': 'test',
#   'sat_image_path': 'test/133160_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 134874,
#   'split': 'test',
#   'sat_image_path': 'test/134874_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 14397,
#   'split': 'test',
#   'sat_image_path': 'test/14397_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 1499,
#   'split': 'test',
#   'sat_image_path': 'test/1499_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 157550,
#   'split': 'test',
#   'sat_image_path': 'test/157550_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 159696,
#   'split': 'test',
#   'sat_image_path': 'test/159696_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 162964,
#   'split': 'test',
#   'sat_image_path': 'test/162964_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 168870,
#   'split': 'test',
#   'sat_image_path': 'test/168870_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 169788,
#   'split': 'test',
#   'sat_image_path': 'test/169788_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 172318,
#   'split': 'test',
#   'sat_image_path': 'test/172318_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 17557,
#   'split': 'test',
#   'sat_image_path': 'test/17557_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 181781,
#   'split': 'test',
#   'sat_image_path': 'test/181781_sat.jpg',
#   'mask_path': nan},
#  {'image_id': 186618,
#   'split': 'test',
#   'sat_image_path': 'test/186618_sat.jpg',
#   'mask_path': nan},
#  ...]

# %%
from numpy import NaN


for image_dict in meta_list:
    split_name = image_dict['split']
    sat_image_name = image_dict['sat_image_path'].split("/")[-1]
    
    if image_dict['mask_path'] not in [None, NaN, ""]:
        mask_image_name = image_dict['mask_path'].split("/")[-1]
    
    if os.path.exists(os.path.join(RAW_DATA_PATH, image_dict['sat_image_path'])):
    
        os.rename(os.path.join(RAW_DATA_PATH, image_dict['sat_image_path']), os.path.join(
            TARGET_DATA_PATH, split_name, f"images/{sat_image_name}"))
        
    
    if image_dict['mask_path'] not in [None, NaN, ""] and os.path.exists(os.path.join(RAW_DATA_PATH, image_dict['mask_path'])):
        os.rename(os.path.join(RAW_DATA_PATH, image_dict['mask_path']), os.path.join(
            TARGET_DATA_PATH, split_name, f"masks/{mask_image_name}"))

# %%
# remove postfix
splits = ["train", "test", "valid"]

for split in splits:
    image_dir_path = os.path.join(TARGET_DATA_PATH, split, "images/")
    mask_dir_path = os.path.join(TARGET_DATA_PATH, split, "masks/")
    
    image_dir = os.listdir(image_dir_path)
    mask_dir = os.listdir(mask_dir_path)
    
    for image_name in image_dir:
        if image_name.endswith((".jpg", ".png", ".jpeg")):
            new_name = image_name.replace("_sat", "")
            os.rename(os.path.join(image_dir_path, image_name), os.path.join(image_dir_path, new_name))
            
    for image_name in mask_dir:
        if image_name.endswith((".jpg", ".png", ".jpeg")):
            new_name = image_name.replace("_mask", "")
            os.rename(os.path.join(mask_dir_path, image_name), os.path.join(mask_dir_path, new_name))

# %%
from sklearn.model_selection import train_test_split

image_dir_path = os.path.join(TARGET_DATA_PATH, "train", "images/")
mask_dir_path = os.path.join(TARGET_DATA_PATH, "train", "masks/")

image_files = sorted(os.listdir(image_dir_path))
mask_files = sorted(os.listdir(mask_dir_path))

# Train-validation split (e.g., 80% train, 20% validation)
train_images, val_images, train_masks, val_masks = train_test_split(
    image_files, mask_files, test_size=0.2, random_state=42
)

# %%
val_image_dir_path = os.path.join(TARGET_DATA_PATH, "val", "images/")
val_mask_dir_path = os.path.join(TARGET_DATA_PATH, "val", "masks/")

for img, mask in zip(val_images, val_masks):
    os.rename(os.path.join(image_dir_path, img), os.path.join(val_image_dir_path, img))
    os.rename(os.path.join(mask_dir_path, mask), os.path.join(val_mask_dir_path, mask))
